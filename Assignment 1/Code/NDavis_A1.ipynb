# %% [markdown]
# # CSC 605 Assignment 1

# %% [markdown]
# Import neccessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Question 1:
#
# Implement a class for n-sided polygons and a class for points in a Euclidean system, namely *polygon* and *point* respectively. For example, a 4-sided polygon can be defined by 4 points P1, P2, P3, P4, and
# P1-P4 are each points of the form point(X,Y), and X and Y are coordinates on the X and Y axis, respectively. The edges are listed counterclockwise starting at the lower left: P1 to P2, P2 to P3, P3 to P4, and P4 to P1.  The polygon class should work for polygons of any number of edges and have a function perimeter that returns its perimeter (sum of the lengths of the edges).

# %% [markdown]
# Question 2:
#
# - Use Pandas to load both data/AIS/transit_segments.csv, and data/AIS/vessel_information.csv. Show the first 5 rows of each dataset to inspect it.
# - For data/AIS/vessel_information.csv, keep only those rows with the type value occurring for at least 100 times in the dataset.
# - Merge data/AIS/vessel_information.csv and data/AIS/transit_segments.csv on the "mmsi" column using outer join.
# - If you are *not* allowed to call the inner join provided by Pandas but have the above outer join results, how to get the results of inner join? You can use other functions provided by Pandas (but not a function that directly implements the inner join).
# - Now directly call the inner join provided by Pandas, check whether your results above are exactly the same.

# %% [markdown]
# ## Read in transit data and print first 5 rows

# %%
transit = pd.read_csv("../Data/transit_segments.csv")
transit.head()
# Out:
#    mmsi               name  transit  segment  seg_length  avg_sog  min_sog  \
# 0     1        Us Govt Ves        1        1         5.1     13.2      9.2
# 1     1  Dredge Capt Frank        1        1        13.5     18.6     10.4
# 2     1      Us Gov Vessel        1        1         4.3     16.2     10.3
# 3     1      Us Gov Vessel        2        1         9.2     15.4     14.5
# 4     1  Dredge Capt Frank        2        1         9.2     15.4     14.6
#
#    max_sog  pdgt10        st_time       end_time
# 0     14.5    96.5  2/10/09 16:03  2/10/09 16:27
# 1     20.6   100.0   4/6/09 14:31   4/6/09 15:20
# 2     20.5   100.0   4/6/09 14:36   4/6/09 14:55
# 3     16.1   100.0  4/10/09 17:58  4/10/09 18:34
# 4     16.2   100.0  4/10/09 17:59  4/10/09 18:35

# %% [markdown]
# ## Read in vessel data and print first 5 rows

# %%
vessel = pd.read_csv("../Data/vessel_information.csv")
vessel.head()
# Out:
#    mmsi  num_names                                              names sov  \
# 0     1          8  Bil Holman Dredge/Dredge Capt Frank/Emo/Offsho...   Y
# 1     9          3                         000000009/Raven/Shearwater   N
# 2    21          1                                      Us Gov Vessel   Y
# 3    74          2                                  Mcfaul/Sarah Bell   N
# 4   103          3           Ron G/Us Navy Warship 103/Us Warship 103   Y
#
#       flag flag_type  num_loas                                    loa  \
# 0  Unknown   Unknown         7  42.0/48.0/57.0/90.0/138.0/154.0/156.0
# 1  Unknown   Unknown         2                              50.0/62.0
# 2  Unknown   Unknown         1                                  208.0
# 3  Unknown   Unknown         1                                  155.0
# 4  Unknown   Unknown         2                             26.0/155.0
#
#    max_loa  num_types                             type
# 0    156.0          4  Dredging/MilOps/Reserved/Towing
# 1     62.0          2                     Pleasure/Tug
# 2    208.0          1                          Unknown
# 3    155.0          1                          Unknown
# 4    155.0          2                   Tanker/Unknown

# %% [markdown]
# ## Keep rows in vessel information where the type occurs more than 100 times

# %%
vessel_tmp = vessel[(vessel['type'] == 'AntiPol')]
vessel_tmp
# Out:
#            mmsi  num_names                                names sov  \
# 2730  303195000          1                          Lynne Frink   N
# 2731  303197000          1                         Nrc Guardian   N
# 5439  366593000          1                   Delaware_responder   N
# 5441  366599000          2  Maine     Responder/Maine Responder   N
# 5442  366602000          1                   Virginia Responder   N
# 6400  367387540          1                          Mark Miller   N
#
#                            flag flag_type  num_loas   loa  max_loa  num_types  \
# 2730         Alaska (State of)   Domestic         1  33.0     33.0          1
# 2731         Alaska (State of)   Domestic         1  27.0     27.0          1
# 5439  United States of America   Domestic         1  70.0     70.0          1
# 5441  United States of America   Domestic         1   0.0      0.0          1
# 5442  United States of America   Domestic         1  70.0     70.0          1
# 6400  United States of America   Domestic         1  22.0     22.0          1
#
#          type
# 2730  AntiPol
# 2731  AntiPol
# 5439  AntiPol
# 5441  AntiPol
# 5442  AntiPol
# 6400  AntiPol

# %% [markdown]
# ## Merge vessel and transit data on the mmsi column via outer join

# %%
merged_data = vessel_type100.join(transit, on="mmsi", how="outer", lsuffix="vessel", rsuffix="transit")
merged_data
# Out:
#               mmsi   mmsivessel  num_names  \
# NaN              0          NaN        NaN
# 0.0              1          1.0        8.0
# NaN              2          NaN        NaN
# NaN              3          NaN        NaN
# NaN              4          NaN        NaN
# ...            ...          ...        ...
# 10766.0  919191919  919191919.0        1.0
# 10767.0  967191190  967191190.0        1.0
# 10768.0  975318642  975318642.0        1.0
# 10769.0  987654321  987654321.0        2.0
# 10770.0  999999999  999999999.0        1.0
#
#                                                      names  sov     flag  \
# NaN                                                    NaN  NaN      NaN
# 0.0      Bil Holman Dredge/Dredge Capt Frank/Emo/Offsho...    Y  Unknown
# NaN                                                    NaN  NaN      NaN
# NaN                                                    NaN  NaN      NaN
# NaN                                                    NaN  NaN      NaN
# ...                                                    ...  ...      ...
# 10766.0                                                 Oi    N  Unknown
# 10767.0                                         Pathfinder    N  Unknown
# 10768.0                                     Island Express    N  Unknown
# 10769.0                         Island Lookout/Island Tide    N  Unknown
# 10770.0                                  Triple Attraction    N  Unknown
#
#         flag_type  num_loas                                    loa  max_loa  \
# NaN           NaN       NaN                                    NaN      NaN
# 0.0       Unknown       7.0  42.0/48.0/57.0/90.0/138.0/154.0/156.0    156.0
# NaN           NaN       NaN                                    NaN      NaN
# NaN           NaN       NaN                                    NaN      NaN
# NaN           NaN       NaN                                    NaN      NaN
# ...           ...       ...                                    ...      ...
# 10766.0   Unknown       1.0                                   20.0     20.0
# 10767.0   Unknown       1.0                                   31.0     31.0
# 10768.0   Unknown       1.0                                   20.0     20.0
# 10769.0   Unknown       2.0                              22.0/23.0     23.0
# 10770.0   Unknown       1.0                                   30.0     30.0
#
#          ...               name transit  segment seg_length  avg_sog  min_sog  \
# NaN      ...        Us Govt Ves     1.0      1.0        5.1     13.2      9.2
# 0.0      ...  Dredge Capt Frank     1.0      1.0       13.5     18.6     10.4
# NaN      ...      Us Gov Vessel     1.0      1.0        4.3     16.2     10.3
# NaN      ...      Us Gov Vessel     2.0      1.0        9.2     15.4     14.5
# NaN      ...  Dredge Capt Frank     2.0      1.0        9.2     15.4     14.6
# ...      ...                ...     ...      ...        ...      ...      ...
# 10766.0  ...                NaN     NaN      NaN        NaN      NaN      NaN
# 10767.0  ...                NaN     NaN      NaN        NaN      NaN      NaN
# 10768.0  ...                NaN     NaN      NaN        NaN      NaN      NaN
# 10769.0  ...                NaN     NaN      NaN        NaN      NaN      NaN
# 10770.0  ...                NaN     NaN      NaN        NaN      NaN      NaN
#
#          max_sog  pdgt10        st_time       end_time
# NaN         14.5    96.5  2/10/09 16:03  2/10/09 16:27
# 0.0         20.6   100.0   4/6/09 14:31   4/6/09 15:20
# NaN         20.5   100.0   4/6/09 14:36   4/6/09 14:55
# NaN         16.1   100.0  4/10/09 17:58  4/10/09 18:34
# NaN         16.2   100.0  4/10/09 17:59  4/10/09 18:35
# ...          ...     ...            ...            ...
# 10766.0      NaN     NaN            NaN            NaN
# 10767.0      NaN     NaN            NaN            NaN
# 10768.0      NaN     NaN            NaN            NaN
# 10769.0      NaN     NaN            NaN            NaN
# 10770.0      NaN     NaN            NaN            NaN
#
# [273285 rows x 23 columns]
